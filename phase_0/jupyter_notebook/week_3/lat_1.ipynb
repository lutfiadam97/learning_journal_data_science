# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data = pd.read_csv('dataset/data-2.csv')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data[(data['UnitPrice'] > 300)]
# Out:
#        InvoiceNo StockCode     Description  Quantity      InvoiceDate  \
# 1814      536544       DOT  DOTCOM POSTAGE         1  12/1/2010 14:32
# 3041      536592       DOT  DOTCOM POSTAGE         1  12/1/2010 17:06
# 5685      536865       DOT  DOTCOM POSTAGE         1  12/3/2010 11:28
# 6165      536876       DOT  DOTCOM POSTAGE         1  12/3/2010 11:36
# 10812     537237       DOT  DOTCOM POSTAGE         1   12/6/2010 9:58
# ...          ...       ...             ...       ...              ...
# 536834    581219       DOT  DOTCOM POSTAGE         1   12/8/2011 9:28
# 537254    581238       DOT  DOTCOM POSTAGE         1  12/8/2011 10:53
# 539368    581439       DOT  DOTCOM POSTAGE         1  12/8/2011 16:30
# 540908    581492       DOT  DOTCOM POSTAGE         1  12/9/2011 10:03
# 541540    581498       DOT  DOTCOM POSTAGE         1  12/9/2011 10:26
#
#         UnitPrice  CustomerID         Country
# 1814       569.77         NaN  United Kingdom
# ...

# %%
data.groupby('Description')['UnitPrice'].sum()
# Out:
# Description
#  4 PURPLE FLOCK DINNER CANDLES    100.67
#  50'S CHRISTMAS GIFT BAG LARGE    185.28
#  DOLLY GIRL BEAKER                271.38
#  I LOVE LONDON MINI BACKPACK      405.80
#  I LOVE LONDON MINI RUCKSACK        4.15
#                                    ...
# wrongly marked carton 22804         0.00
# wrongly marked. 23343 in box        0.00
# wrongly sold (22719) barcode        0.00
# wrongly sold as sets                0.00
# wrongly sold sets                   0.00
# Name: UnitPrice, Length: 4223, dtype: float64

# %%
data['Revenue'] = data['Quantity']*data['UnitPrice']

# %%
data.groupby("CustomerID")['Revenue'].sum()
# Out:
# CustomerID
# 12346.0       0.00
# 12347.0    4310.00
# 12348.0    1797.24
# 12349.0    1757.55
# 12350.0     334.40
#             ...
# 18280.0     180.60
# 18281.0      80.82
# 18282.0     176.60
# 18283.0    2094.88
# 18287.0    1837.28
# Name: Revenue, Length: 4372, dtype: float64

# %%
data.groupby(["CustomerID", "Country"])['Revenue'].max()
# Out:
# CustomerID  Country
# 12346.0     United Kingdom    77183.60
# 12347.0     Iceland             249.60
# 12348.0     Finland             240.00
# 12349.0     Italy               300.00
# 12350.0     Norway               40.00
#                                 ...
# 18280.0     United Kingdom       23.70
# 18281.0     United Kingdom       16.95
# 18282.0     United Kingdom       25.50
# 18283.0     United Kingdom       20.80
# 18287.0     United Kingdom       87.00
# Name: Revenue, Length: 4380, dtype: float64

# %%
data.groupby(["CustomerID", "Country"])['Revenue'].sum()
# Out:
# CustomerID  Country
# 12346.0     United Kingdom       0.00
# 12347.0     Iceland           4310.00
# 12348.0     Finland           1797.24
# 12349.0     Italy             1757.55
# 12350.0     Norway             334.40
#                                ...
# 18280.0     United Kingdom     180.60
# 18281.0     United Kingdom      80.82
# 18282.0     United Kingdom     176.60
# 18283.0     United Kingdom    2094.88
# 18287.0     United Kingdom    1837.28
# Name: Revenue, Length: 4380, dtype: float64

# %%
data.groupby("Country")['Revenue'].sum()
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# ...

# %%
data[data['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID        Revenue
# count  541909.000000  541909.000000  406829.000000  541909.000000
# mean        9.552250       4.611114   15287.690570      17.987795
# std       218.081158      96.759853    1713.600303     378.810824
# min    -80995.000000  -11062.060000   12346.000000 -168469.600000
# 25%         1.000000       1.250000   13953.000000       3.400000
# 50%         3.000000       2.080000   15152.000000       9.750000
# 75%        10.000000       4.130000   16791.000000      17.400000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
data[data['Revenue']>0].sort_values(['InvoiceDate']).reset_index()
# Out:
#          index InvoiceNo StockCode                         Description  \
# 0        50815    540561     21232      STRAWBERRY CERAMIC TRINKET BOX
# 1        50816    540561     84580         MOUSE TOY WITH PINK T-SHIRT
# 2        50831    540561     22743  MAKE YOUR OWN FLOWERPOWER CARD KIT
# 3        50830    540561     84581     DOG TOY WITH PINK CROCHET SKIRT
# 4        50829    540561    47567B              TEA TIME KITCHEN APRON
# ...        ...       ...       ...                                 ...
# 530099  332551    566079     22396       MAGNETS PACK OF 4 RETRO PHOTO
# 530100  332552    566079     22398          MAGNETS PACK OF 4 SWALLOWS
# 530101  332553    566079     22403   MAGNETS PACK OF 4 VINTAGE LABELS
# 530102  332546    566079     23432       PRETTY HANGING QUILTED HEARTS
# 530103  332538    566079     23334            IVORY WICKER HEART SMALL
#
#         Quantity      InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
data[(data['Revenue']<0)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
data_without_UK = data.copy()

# %%
data_without_UK = data_without_UK[data_without_UK['Country'] != 'United Kingdom']

# %%
data_without_UK
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country  Revenue
# ...

# %%
data_without_UK.describe()
# Out:
#            Quantity     UnitPrice    CustomerID       Revenue
# count  46431.000000  46431.000000  44951.000000  46431.000000
# mean      19.655424      5.450852  13193.105203     33.596984
# std       47.233708     63.360527   1085.609495    104.425951
# min     -624.000000      0.000000  12347.000000  -8322.120000
# 25%        4.000000      1.250000  12484.000000     12.500000
# 50%       10.000000      1.950000  12658.000000     17.400000
# 75%       16.000000      3.750000  14156.000000     30.000000
# max     2400.000000   4161.060000  17844.000000   4992.000000

# %%
data_without_UK["Revenue"].mean()
# Out:
# 33.59698412698446

# %%
data_without_UK.groupby("Country")['Revenue'].sum().sort_values()
# Out:
# Country
# Saudi Arabia               131.17
# Bahrain                    548.40
# Czech Republic             707.72
# RSA                       1002.31
# Brazil                    1143.60
# European Community        1291.75
# Lithuania                 1661.06
# Lebanon                   1693.88
# USA                       1730.92
# United Arab Emirates      1902.28
# Malta                     2505.47
# Canada                    3666.38
# Iceland                   4310.00
# Greece                    4710.52
# Unspecified               4749.79
# Poland                    7213.14
# Israel                    7907.82
# Singapore                 9120.39
# Hong Kong                10117.04
# Austria                  10154.32
# Cyprus                   12946.29
# Italy                    16890.51
# Denmark                  18768.14
# Channel Islands          20086.29
# Finland                  22326.74
# Portugal                 29367.02
# Norway                   35163.46
# ...

# %%
data_without_UK.groupby("Country")['Revenue'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data_without_UK[(data_without_UK['Country'] == 'Netherlands')]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 385       536403     22867            HAND WARMER BIRD DESIGN        96
# 386       536403      POST                            POSTAGE         1
# 37952     539491     21981       PACK OF 12 WOODLAND TISSUES         12
# 37953     539491     21986   PACK OF 12 PINK POLKADOT TISSUES        12
# 37954     539491     22720  SET OF 3 CAKE TINS PANTRY DESIGN          2
# ...          ...       ...                                ...       ...
# 534958    581176     22908      PACK OF 20 NAPKINS RED APPLES        96
# 534959    581176     22907   PACK OF 20 NAPKINS PANTRY DESIGN        96
# 534960    581176     22029             SPACEBOY BIRTHDAY CARD        72
# 534961    581176     22712                   CARD DOLLY GIRL         72
# 537783    581338     23344          JUMBO BAG 50'S CHRISTMAS        140
#
#                InvoiceDate  UnitPrice  CustomerID      Country  Revenue  \
# ...

# %%
data_without_UK[(data_without_UK['Quantity']>0) &
                (data_without_UK['Country'] == 'Netherlands')
               ].sort_values(['InvoiceDate']).reset_index()
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0      57467    541206     22467                    GUMBALL COAT RACK
# 1      57401    541206     21428  SET3 BOOK BOX GREEN GINGHAM FLOWER
# 2      57400    541206     21430   SET/3 RED GINGHAM ROSE STORAGE BOX
# 3      57399    541206     21429       RED GINGHAM ROSE JEWELLERY BOX
# 4      57398    541206     22759         SET OF 3 NOTEBOOKS IN PARCEL
# ...      ...       ...       ...                                  ...
# 2358  333117    566173     22342           HOME GARLAND PAINTED ZINC
# 2359  333115    566173     22341           LOVE GARLAND PAINTED ZINC
# 2360  333114    566173     22078             RIBBON REEL LACE DESIGN
# 2361  333121    566173      POST                              POSTAGE
# 2362  333116    566173     22567              20 DOLLY PEGS RETROSPOT
#
#       Quantity      InvoiceDate  UnitPrice  CustomerID      Country  Revenue
# ...

# %%
data_without_UK[(data_without_UK['Quantity']>0) &
                (data_without_UK['Country'] == 'Germany')
               ].sort_values(['InvoiceDate']).reset_index()
# Out:
#        index InvoiceNo StockCode                       Description  Quantity  \
# 0       1109    536527     22809           SET OF 6 T-LIGHTS SANTA         6
# 1       1123    536527      POST                           POSTAGE         1
# 2       1122    536527     22549                  PICTURE DOMINOES        12
# 3       1121    536527    84569B    PACK 3 FIRE ENGINE/CAR PATCHES        12
# 4       1120    536527     22973      CHILDREN'S CIRCUS PARADE MUG        12
# ...      ...       ...       ...                               ...       ...
# 9037  541781    581578     22549                  PICTURE DOMINOES        24
# 9038  541782    581578     21918  SET 12 KIDS COLOUR  CHALK STICKS        24
# 9039  541783    581578     22992            REVOLVER WOODEN RULER         12
# 9040  541775    581578     23255   CHILDRENS CUTLERY CIRCUS PARADE        12
# 9041  541805    581578     22736       RIBBON REEL MAKING SNOWMEN         10
#
# ...

# %%
data_without_UK["InvoiceDate"] = pd.to_datetime(data_without_UK["InvoiceDate"])

# %%
data_without_UK["InvoiceDate"]
# Out:
# 26       2010-12-01 08:45:00
# 27       2010-12-01 08:45:00
# 28       2010-12-01 08:45:00
# 29       2010-12-01 08:45:00
# 30       2010-12-01 08:45:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 46431, dtype: datetime64[ns]

# %%
#data_without_UK[data_without_UK["Country"] == 'Netherland'].sort_values(['Date','Time'])

data_without_UK['Month'] = data_without_UK['InvoiceDate'].dt.month

# %%
data_without_UK
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country  Revenue  Month
# ...

# %%
data_without_UK['Year'] = data_without_UK['InvoiceDate'].dt.year

# %%
data_without_UK
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country  Revenue  Month  \
# ...

# %%
data_without_UK[data_without_UK["Country"] == 'Germany'].groupby(['Year','Month'])["Revenue"].sum()
# Out:
# Year  Month
# 2010  12       14562.84
# 2011  1        16451.43
#       2         8969.24
#       3        14170.02
#       4        11963.37
#       5        25571.35
#       6        13081.02
#       7        15721.66
#       8        19023.65
#       9        17720.31
#       10       30614.27
#       11       26044.35
#       12        7804.70
# Name: Revenue, dtype: float64

# %%
data_without_UK[data_without_UK["Country"] == 'Germany'].groupby(['Year','Month'])["Revenue"].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year,Month'>
