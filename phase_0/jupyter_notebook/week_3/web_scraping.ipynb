# %% [markdown]
# # Web Scraping

# %%
# akses buku-buku di gramedia
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://cdn.

# %%
soup.find_all('div',{"class":"list-title"})
# Out:
# [<div _ngcontent-web-gramedia-c26="" class="list-title">A+</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Lavender</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">30 Doa Salafush Shalih</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Ramuan Tradisional Anti Segala Virus</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Malaikat Di Sisi Kita</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Buku Bisakah Aku yang Pelupa Memiliki Ingatan Super?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">The Art of Self Talk-ing</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Paket Pandai Baca Tulis Hitung Anak Umur Paud / Tk</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kisah 25 Nabi Dan Khulafaur Rasyidin</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Indonesia Sebagai Poros Maritim Dunia</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kitab Lulus Utbk Sbmptn Saintek 2022</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Pendidikan Untuk Apa dan Untuk Siapa?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Topi Jerami Lu</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Apakah Lu diculik?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kenduri Arwah</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Intelijen dan Kekuasaan Soeharto</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">KOLONI Sinawang</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Plants VS Zombies - Komik Dinosaurus : Berburu Harta Karun di Periode Jura</div>]

# %% [markdown]
# Lihat isi semua elemen div, class: list-title. Tapi kita butuh text judul buku saja. Pake get_text() untuk mengekstraknya.

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# A+
# Lavender
# Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 30 Doa Salafush Shalih
# Ramuan Tradisional Anti Segala Virus
# Malaikat Di Sisi Kita
# Buku Bisakah Aku yang Pelupa Memiliki Ingatan Super?
# The Art of Self Talk-ing
# Paket Pandai Baca Tulis Hitung Anak Umur Paud / Tk
# Kisah 25 Nabi Dan Khulafaur Rasyidin
# Indonesia Sebagai Poros Maritim Dunia
# Kitab Lulus Utbk Sbmptn Saintek 2022
# Pendidikan Untuk Apa dan Untuk Siapa?
# Petualangan Lu si Ulat Bulu : Topi Jerami Lu
# Petualangan Lu si Ulat Bulu : Apakah Lu diculik?
# Kenduri Arwah
# Intelijen dan Kekuasaan Soeharto
# Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu
# KOLONI Sinawang
# Plants VS Zombies - Komik Dinosaurus : Berburu Harta Karun di Periode Jura

# %%
import pandas as pd

data_buku = pd.DataFrame()

data_buku['Title'] = [title.get_text() for title in soup.find_all('div', {"class":"list-title"})]
data_buku['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data_buku['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data_buku['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data_buku['Link'] = links

data_buku
# Out:
#                                                 Title  \
# 0                                     KOLONI Sinawang
# 1   Plants VS Zombies - Komik Dinosaurus : Berburu...
# 2   Plants VS Zombies - Komik Dinosaurus : Pertaru...
# 3   Akasha : Re: Zero, Starting Life In Another Wo...
# 4        AKASHA : Wotakoi : Love is Hard for Otaku 04
# 5                  Haikyu!!: Fly High! Volleyball! 27
# 6                                     LC: BLOOD LAD 9
# 7                                      Shaka Oh Shaka
# 8                            LC: Shiomi-chan 05 (END)
# 9              YOUTH X MACHINEGUN Aoharu x Kikanju 01
# 10                  The Quintessential Quintuplets 14
# 11                             365 Aktivitas TOP PAUD
# 12                Job? Akulah Ahlinya Baking & Pastry
# 13                     Media Sosial, Suatu Alternatif
# 14        Wanita-wanita Tangguh di Sekitar Rasulullah
# 15                               Semua Bisa Investasi
# 16  Artificial Intelligence: Perspektif Manajemen ...
# 17      55+ Aktivitas Calistung Mengenal Fungsi Benda
# 18               55+ Aktivitas Calistung Anak GEMBIRA
# 19                            YU-GI-OH ! (Premium) 21
#
#                                                Author       Price  \
# 0                           Dedy Koerniawan Soesanto    Rp 36.000
# 1                                      Xiao Jiangnan    Rp 84.000
# 2                                      Xiao Jiangnan    Rp 84.000
# 3                  TAPPEI NAGATSUKI  FUUGETSU Makoto    Rp 36.000
# 4                                            FUJITA     Rp 32.000
# 5                                  Haruichi Furudate    Rp 22.400
# 6                                       Yuuki KODAMA    Rp 24.000
# 7                                   Jocelyn Suherman    Rp 84.150
# 8                                      Inoue Kazurou    Rp 32.000
# 9                                          Naoe None    Rp 36.000
# 10                                       Negi Haruba    Rp 40.000
# 11                                   Kanaya Larasati    Rp 64.000
# 12                                  Kugil Publishing    Rp 80.000
# 13    DR. H. DAS`AD LATIF, S. SOS, S. AG, M.SI, PH.D    Rp 48.000
# 14   Mahmud Mahdi Al Istanbuli  Musthafa Abu Nashr...   Rp 92.000
# 15                                 Thomas Athanasius    Rp 48.000
# 16                  Manerep Pasaribu  Albert Widjaja   Rp 124.000
# 17                                    A. TABI`IN DKK    Rp 47.200
# 18                                    A. TABI`IN DKK    Rp 47.200
# 19                                  Kazuki Takahashi    Rp 17.850
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/cov_SIN...
# 1   https://cdn.gramedia.com/uploads/items/cover_H...
# 2   https://cdn.gramedia.com/uploads/items/cover_P...
# 3   https://cdn.gramedia.com/uploads/items/COV_RE_...
# 4   https://cdn.gramedia.com/uploads/items/COV_WOT...
# 5   https://cdn.gramedia.com/uploads/items/cover_h...
# 6   https://cdn.gramedia.com/uploads/items/9786230...
# 7   https://cdn.gramedia.com/uploads/items/img2022...
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/koloni-sinawang
# 1   https://www.gramedia.com/products/plants-vs-zo...
# 2   https://www.gramedia.com/products/plants-vs-zo...
# 3   https://www.gramedia.com/products/akasha-re-ze...
# 4   https://www.gramedia.com/products/akasha-wotak...
# 5   https://www.gramedia.com/products/haikyu-fly-h...
# 6    https://www.gramedia.com/products/lc-blood-lad-9
# 7    https://www.gramedia.com/products/shaka-oh-shaka
# 8   https://www.gramedia.com/products/lc-shiomi-ch...
# 9   https://www.gramedia.com/products/youth-x-mach...
# 10  https://www.gramedia.com/products/the-quintess...
# 11  https://www.gramedia.com/products/365-aktivita...
# 12  https://www.gramedia.com/products/job-akulah-a...
# 13  https://www.gramedia.com/products/media-sosial...
# 14  https://www.gramedia.com/products/wanita-wanit...
# 15  https://www.gramedia.com/products/semua-bisa-i...
# 16  https://www.gramedia.com/products/artificial-i...
# 17  https://www.gramedia.com/products/55-aktivitas...
# 18  https://www.gramedia.com/products/55-aktivitas...
# 19  https://www.gramedia.com/products/yu-gi-oh-pre...

# %% [markdown]
# ## Multiple Page

# %%
from time import sleep
from random import randint

title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,11): #halaman 1 sampai halaman 20
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    sleep(randint(20,25)) # nunggu halamannya ngeload sampai 20-25
    #while len(title) == 0:
        #sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                                                   A+
# 1                                             Lavender
# 2       Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 3                               30 Doa Salafush Shalih
# 4                 Ramuan Tradisional Anti Segala Virus
# ..                                                 ...
# 195                         Opredo Paket Poster Islami
# 196                   Kumpulan Kisah Keajaiban Berbagi
# 197        Why? Bacteria and Virus - Bakteri dan Virus
# 198                 Tuhan, Kenapa Jodohku Belum Datang
# 199  Setiap Pebisnis Harus Punya Buku Ini! - New Ed...
#
#                               Author       Price  \
# 0                      Ananda Putri    Rp 84.575
# 1               Astri Salvia Aznani    Rp 80.750
# 2     Prof. Dr. Muhammad az-Zuhaili   Rp 204.000
# 3                         OMAR None    Rp 58.650
# 4                    Argo Wikanjati    Rp 51.000
# ..                               ...         ...
# 195                    Tim Oopredoo    Rp 60.000
# 196           Fajriatun Nurhidayati    Rp 76.000
# 197                     YeaRimDang     Rp 88.000
# 198                        A.K None    Rp 64.000
# 199                    Dini Hertita    Rp 64.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/A__w149...
# 1    https://cdn.gramedia.com/uploads/items/Lavende...
# 2                   /assets/default-images/product.png
# 3    https://cdn.gramedia.com/uploads/items/30_Doa_...
# 4    https://cdn.gramedia.com/uploads/items/Ramuan_...
# ..                                                 ...
# 195                 /assets/default-images/product.png
# 196                 /assets/default-images/product.png
# 197                 /assets/default-images/product.png
# 198                 /assets/default-images/product.png
# 199                 /assets/default-images/product.png
#
#                                                   Link
# 0                https://www.gramedia.com/products/a-3
# 1           https://www.gramedia.com/products/lavender
# 2    https://www.gramedia.com/products/fiqih-al-mut...
# 3    https://www.gramedia.com/products/30-doa-salaf...
# 4    https://www.gramedia.com/products/ramuan-tradi...
# ..                                                 ...
# 195  https://www.gramedia.com/products/opredo-paket...
# 196  https://www.gramedia.com/products/kumpulan-kis...
# 197  https://www.gramedia.com/products/why-bacteria...
# 198  https://www.gramedia.com/products/tuhan-kenapa...
# 199  https://www.gramedia.com/products/setiap-pebis...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Accessing Individual Page

# %%
title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    sleep(randint(15,20))
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            sleep(randint(15,20))
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
#                                                 Title  \
# 0                      Jangan Pusingkan Omongan Orang
# 1                                  Un1Ty In Diversity
# 2                                                  A+
# 3                                            Lavender
# 4      Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 5                              30 Doa Salafush Shalih
# 6                Ramuan Tradisional Anti Segala Virus
# 7                               Malaikat Di Sisi Kita
# 8   Buku Bisakah Aku yang Pelupa Memiliki Ingatan ...
# 9                            The Art of Self Talk-ing
# 10  Paket Pandai Baca Tulis Hitung Anak Umur Paud ...
# 11               Kisah 25 Nabi Dan Khulafaur Rasyidin
# 12              Indonesia Sebagai Poros Maritim Dunia
# 13               Kitab Lulus Utbk Sbmptn Saintek 2022
# 14              Pendidikan Untuk Apa dan Untuk Siapa?
# 15       Petualangan Lu si Ulat Bulu : Topi Jerami Lu
# 16   Petualangan Lu si Ulat Bulu : Apakah Lu diculik?
# 17                                      Kenduri Arwah
# 18                   Intelijen dan Kekuasaan Soeharto
# 19    Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu
# 20                                    KOLONI Sinawang
# 21  Plants VS Zombies - Komik Dinosaurus : Berburu...
# 22  Plants VS Zombies - Komik Dinosaurus : Pertaru...
# 23  Akasha : Re: Zero, Starting Life In Another Wo...
# 24       AKASHA : Wotakoi : Love is Hard for Otaku 04
# 25                 Haikyu!!: Fly High! Volleyball! 27
# 26                                    LC: BLOOD LAD 9
# 27                                     Shaka Oh Shaka
# 28                           LC: Shiomi-chan 05 (END)
# 29             YOUTH X MACHINEGUN Aoharu x Kikanju 01
# 30                  The Quintessential Quintuplets 14
# 31                             365 Aktivitas TOP PAUD
# 32                Job? Akulah Ahlinya Baking & Pastry
# 33                     Media Sosial, Suatu Alternatif
# 34        Wanita-wanita Tangguh di Sekitar Rasulullah
# 35                               Semua Bisa Investasi
# 36  Artificial Intelligence: Perspektif Manajemen ...
# 37      55+ Aktivitas Calistung Mengenal Fungsi Benda
# 38               55+ Aktivitas Calistung Anak GEMBIRA
# 39                              Yu-Gi-Oh (Premium) 21
#
#                                             Author                 Price  \
# 0                                  Fitri Handayani   Rp 85.000Rp 100.000
# 1                                            Un1Ty  Rp 208.000Rp 260.000
# 2                                     Ananda Putri    Rp 84.575Rp 99.500
# 3                              Astri Salvia Aznani    Rp 80.750Rp 95.000
# 4                    Prof. Dr. Muhammad az-Zuhaili  Rp 204.000Rp 240.000
# 5                                             OMAR    Rp 58.650Rp 69.000
# 6                                   Argo Wikanjati    Rp 51.000Rp 60.000
# 7                                     Omar Suleman    Rp 58.650Rp 69.000
# 8                                   Cho Shin Young  Rp 100.000Rp 125.000
# 9                                 Nisrina P. Utami    Rp 56.000Rp 70.000
# 10                                        Kak Elly    Rp 67.150Rp 79.000
